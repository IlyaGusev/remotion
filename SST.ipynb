# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
# %%writefile configs/sst2_config.json
# {
#     "batch_size": 32,
#     "competition": "sst2",
#     "data_config": {
#         "clear_cache": true,
#         "domain": "films",
#         "language": "en",
#         "test_filename": "/media/yallen/My Passport/Datasets/Sentiment/SST2/stsa.binary.test.txt",
#         "train_filename": "/media/yallen/My Passport/Datasets/Sentiment/SST2/stsa.binary.train.txt"
#     },
#     "epochs": 100,
#     "optimizer": "adam",
#     "model_config": {
#         "char_dropout_p": 0.4,
#         "char_embedding_dim": 15,
#         "char_function_output_size": 100,
#         "char_max_word_length": 30,
#         "dense_dropout_p": 0.4,
#         "dense_size": 32,
#         "gram_dropout_p": 0.4,
#         "gram_hidden_size": 32,
#         "is_sequence_predictor": false,
#         "rnn_bidirectional": true,
#         "rnn_dropout_p": 0.5,
#         "rnn_hidden_size": 32,
#         "rnn_n_layers": 2,
#         "rnn_output_dropout_p": 0.4,
#         "use_additional_features": false,
#         "use_chars": false,
#         "use_crf": false,
#         "use_pos": true,
#         "use_rnn": true,
#         "use_cnn": false,
#         "use_dense": true,
#         "use_word_embeddings": true,
#         "word_embedding_dim": 300,
#         "word_embedding_dropout_p": 0.4,
#         "word_max_count": 70
#     },
#     "patience": 3,
#     "result_type": "txt",
#     "experiment": "base",
#     "task_type": "clf",
#     "use_pretrained_embedding": true,
#     "train_embeddings": true,
#     "lower_vocabulary": false,
#     "embeddings_filename": "embeddings/sst2-w2v.txt",
#     "val_size": 0.05,
#     "seed": 42
# }
# Out:
# Overwriting configs/sst2_config.json

# %%
# !python3.6 main.py configs/sst2_config.json
# Out:
# /usr/local/lib/python3.6/dist-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.
# [nltk_data] Downloading package wordnet to /home/yallen/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /home/yallen/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package universal_tagset to
# [nltk_data]     /home/yallen/nltk_data...
# [nltk_data]   Package universal_tagset is already up-to-date!
# ...

# %%
# !python3 eval/sst.py -g "/media/yallen/My Passport/Datasets/Sentiment/SST2/stsa.binary.test.txt" -t "submissions/sst2_en_films_clf_base.txt"
# Out:
# Accuracy: 0.851

# %%
# %%writefile configs/sst2_config_exp.json
# {
#     "batch_size": 32,
#     "competition": "sst2",
#     "data_config": {
#         "clear_cache": true,
#         "domain": "films",
#         "language": "en",
#         "test_filename": "/media/yallen/My Passport/Datasets/Sentiment/SST2/stsa.binary.test.txt",
#         "train_filename": "/media/yallen/My Passport/Datasets/Sentiment/SST2/stsa.binary.train.txt"
#     },
#     "epochs": 100,
#     "optimizer": "adam",
#     "model_config": {
#         "char_dropout_p": 0.4,
#         "char_embedding_dim": 15,
#         "char_function_output_size": 100,
#         "char_max_word_length": 30,
#         "dense_dropout_p": 0.4,
#         "dense_size": 32,
#         "gram_dropout_p": 0.4,
#         "gram_hidden_size": 32,
#         "is_sequence_predictor": false,
#         "rnn_bidirectional": true,
#         "rnn_dropout_p": 0.5,
#         "rnn_hidden_size": 32,
#         "rnn_n_layers": 2,
#         "rnn_output_dropout_p": 0.4,
#         "use_additional_features": false,
#         "use_chars": false,
#         "use_crf": false,
#         "use_pos": true,
#         "use_rnn": true,
#         "use_cnn": false,
#         "use_dense": true,
#         "use_word_embeddings": true,
#         "word_embedding_dim": 300,
#         "word_embedding_dropout_p": 0.4,
#         "word_max_count": 70
#     },
#     "patience": 3,
#     "result_type": "txt",
#     "experiment": "exp",
#     "task_type": "clf",
#     "use_pretrained_embedding": true,
#     "train_embeddings": true,
#     "lower_vocabulary": false,
#     "embeddings_filename": "embeddings/sst2-w2v.txt",
#     "val_size": 0.05,
#     "seed": 42
# }
# Out:
# Writing configs/sst2_config_exp.json

# %%
# !python3.6 main.py configs/sst2_config_exp.json
# Out:
# /usr/local/lib/python3.6/dist-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.
# [nltk_data] Downloading package wordnet to /home/yallen/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /home/yallen/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package universal_tagset to
# [nltk_data]     /home/yallen/nltk_data...
# [nltk_data]   Package universal_tagset is already up-to-date!
# ...

# %%
# !python3 eval/sst.py -g "/media/yallen/My Passport/Datasets/Sentiment/SST2/stsa.binary.test.txt" -t "submissions/sst2_en_films_clf_exp.txt"
# Out:
# Accuracy: 0.855

# %%
# %%writefile configs/sst1_config.json
# {
#     "batch_size": 32,
#     "competition": "sst1",
#     "data_config": {
#         "clear_cache": true,
#         "domain": "films",
#         "language": "en",
#         "test_filename": "/media/yallen/My Passport/Datasets/Sentiment/SST1/stsa.fine.test.txt",
#         "train_filename": "/media/yallen/My Passport/Datasets/Sentiment/SST1/stsa.fine.train.txt"
#     },
#     "epochs": 100,
#     "optimizer": "adam",
#     "model_config": {
#         "char_dropout_p": 0.4,
#         "char_embedding_dim": 15,
#         "char_function_output_size": 100,
#         "char_max_word_length": 30,
#         "dense_dropout_p": 0.4,
#         "dense_size": 32,
#         "gram_dropout_p": 0.4,
#         "gram_hidden_size": 32,
#         "is_sequence_predictor": false,
#         "rnn_bidirectional": true,
#         "rnn_dropout_p": 0.5,
#         "rnn_hidden_size": 32,
#         "rnn_n_layers": 2,
#         "rnn_output_dropout_p": 0.4,
#         "use_additional_features": false,
#         "use_chars": false,
#         "use_crf": false,
#         "use_pos": true,
#         "use_rnn": true,
#         "use_cnn": false,
#         "use_dense": true,
#         "use_word_embeddings": true,
#         "word_embedding_dim": 300,
#         "word_embedding_dropout_p": 0.4,
#         "word_max_count": 70,
#         "output_size": 5
#     },
#     "patience": 3,
#     "result_type": "txt",
#     "experiment": "base",
#     "task_type": "clf",
#     "use_pretrained_embedding": true,
#     "train_embeddings": false,
#     "lower_vocabulary": false,
#     "embeddings_filename": "embeddings/sst1-w2v.txt",
#     "val_size": 0.05,
#     "seed": 42
# }
# Out:
# Overwriting configs/sst1_config.json

# %%
# !python3.6 main.py configs/sst1_config.json
# Out:
# /usr/local/lib/python3.6/dist-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.
# [nltk_data] Downloading package wordnet to /home/yallen/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /home/yallen/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package universal_tagset to
# [nltk_data]     /home/yallen/nltk_data...
# [nltk_data]   Package universal_tagset is already up-to-date!
# ...

# %%
# !python3 eval/sst.py -g "/media/yallen/My Passport/Datasets/Sentiment/SST1/stsa.fine.test.txt" -t "submissions/sst1_en_films_clf_base.txt"
# Out:
# Accuracy: 0.453
